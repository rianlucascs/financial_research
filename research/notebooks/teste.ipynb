# %%
from pipelines.readers.cvm_formulario_demonstracoes_financeiras_padronizadas import ReaderCVMFormularioDemonstracoesFinanceirasPadronizadas

reader_dfp = ReaderCVMFormularioDemonstracoesFinanceirasPadronizadas()
reader_dfp = reader_dfp.read(ticker="VALE3", tipo_arquivo="BPA_con")

# %%
from pipelines.readers.cvm_balanco_patrimonial import ReaderCVMBalancoPatrimonial

reader_balanco = ReaderCVMBalancoPatrimonial()

df = reader_balanco.read(ticker="VALE3", tipo_arquivo="BPA_con", cd_conta="1")

df
# Out:
#          Date  VALE_S.A._Ativo_Total
# 0  2011-03-31            217320211.0
# 1  2011-03-31            217320211.0
# 2  2011-06-30            222235600.0
# 3  2011-06-30            222235600.0
# 4  2011-09-30            239097330.0
# ..        ...                    ...
# 87 2025-06-30            493226000.0
# 88 2025-09-30            484953000.0
# 89 2025-09-30            484953000.0
# 90 2026-03-31            457173000.0
# 91 2026-03-31            457173000.0
#
# [92 rows x 2 columns]

# %%
from research.quant.teste import A

A()
# Out:
# ASDASDASDA

# %%
from pipelines.readers.b3_indices_segmentos_setoriais import ReaderB3IndicesSegmentosSetoriais

reader = ReaderB3IndicesSegmentosSetoriais()

reader.read(indice="IDIV")
# Out:
#    Indice Data Referencia  Código          Ação        Tipo  Qtde. Teórica  \
# 0    IDIV      2026-07-06   ABCB4    ABC BRASIL  PN  EJS N2       97361003
# 1    IDIV      2026-07-06   ALOS3         ALLOS  ON      NM      590258296
# 2    IDIV      2026-07-06   AXIA3  AXIA ENERGIA  ON      NM      361318461
# 3    IDIV      2026-07-06   BRSR6      BANRISUL  PNB     N1      249810128
# 4    IDIV      2026-07-06   BBSE3  BBSEGURIDADE  ON      NM      760086076
# 5    IDIV      2026-07-06  BRBI11   BR PARTNERS  UNT     N2       58263812
# 6    IDIV      2026-07-06   BBDC3      BRADESCO  ON  EJ  N1     1398110000
# 7    IDIV      2026-07-06   BBDC4      BRADESCO  PN  EJ  N1     1141114941
# 8    IDIV      2026-07-06   BRAP4     BRADESPAR  PN      N1      309480286
# 9    IDIV      2026-07-06   SAUD3     BRADSAUDE  ON  EJ  NM      310493238
# 10   IDIV      2026-07-06   BBAS3        BRASIL  ON      NM     1118618972
# ...
