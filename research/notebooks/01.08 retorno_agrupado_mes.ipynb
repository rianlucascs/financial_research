# %%
from yfinance import download
import plotly.express as px
from dateutil.relativedelta import relativedelta

# %%
ativo = "^BVSP"
df = download(ativo, period="10y", interval="1d", progress=False, auto_adjust=False).droplevel(1, axis=1)

df['ret'] = df['Close'].pct_change()
df['mes'] = df.index.month
df['ano'] = df.index.year

tabela = (
    df.groupby(['ano', 'mes'])[['ret']]
    .sum()
    .reset_index()
    .pivot(index='ano', columns='mes', values='ret')
) * 100

# %%
for i in range(1, 13):
    print(f"Mês {i}: {tabela[i].mean()}")
# Out:
# Mês 1: 4.664234060352923
# Mês 2: -1.5547810728672262
# Mês 3: -1.698577588463462
# Mês 4: 0.9730966988302303
# Mês 5: -0.10335781986010924
# Mês 6: 0.7207560383970035
# Mês 7: 3.206872576398338
# Mês 8: 1.2911596279342388
# Mês 9: 0.3605757323787818
# Mês 10: 1.9848202715856502
# Mês 11: 2.2149071105355533
# Mês 12: 2.150628026794568

# %%
fig = px.imshow(
    tabela,
    text_auto='.5f',            # anotações com 5 casas
    color_continuous_scale='RdYlGn',
    color_continuous_midpoint=0,  # centro em zero
    aspect='auto'
)

fig.update_layout(
    title=dict(
        text=f'Retorno Ano e Mês - {ativo}',
        x=0.5,
        xanchor='center',
        font=dict(size=18)
    ),
    coloraxis_colorbar=dict(
        title='Retorno Médio',
        len=0.8
    ),
    xaxis=dict(
        title='',
        tickangle=0
    ),
    yaxis=dict(
        title=''
    ),
    height=500,
    template='plotly_white',
)

# Rodapé
fig.add_annotation(
    text=f"<i>Intervalo do retorno: 1d | Período: 10y | Fonte: Yahoo Finance</i>",
    xref='paper',
    yref='paper',
    x=0.5,
    y=-0.12,
    showarrow=False,
    font=dict(
        size=11,
        color='gray'
    ),
    xanchor='center'
)

fig.show()
