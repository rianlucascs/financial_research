# %% [markdown]
# # Diagnóstico preliminar da qualidade dos dados, incluindo shape, nulos, tipos e duplicados.

# %%
from pipelines.readers.pipelines.cvm_cias_abertas_informacao_cadastral.reader_parquet_cvm import ReaderSnapshotParquet as cias_abertas

# %%
df = cias_abertas().read()

# %%
df.tail(3)
# Out:
#                 CNPJ_CIA                              DENOM_SOCIAL  \
# 2674  24.744.012/0001-99                          ZH OPERAÇÕES S/A
# 2675  92.749.217/0001-17                         ZIVI SA CUTELARIA
# 2676  74.533.787/0001-93  ZOGBI LEASING S/A ARRENDAMENTO MERCANTIL
#
#           DENOM_COMERC     DT_REG   DT_CONST  DT_CANCEL  \
# 2674  ZH OPERAÇÕES S/A 2016-09-16 2016-04-15 2017-08-07
# 2675          ZIVI S/A 1968-11-01 1931-01-01 2003-12-29
# 2676     ZOGBI LEASING 1997-09-18 1993-06-18 2004-12-23
#
#                                          MOTIVO_CANCEL        SIT DT_INI_SIT  \
# 2674                            CANCELAMENTO DE OFÍCIO  CANCELADA 2017-08-07
# 2675                           ELISÃO POR INCORPORAÇÃO  CANCELADA 2003-12-29
# 2676  ATENDIMENTO AS NORMAS DA INSTRUÇÃO CVM Nº 361/02  CANCELADA 2004-12-23
#
#      CD_CVM  ... UF_RESP PAIS_RESP  CEP_RESP DDD_TEL_RESP  TEL_RESP  \
# 2674  24007  ...      SP      <NA>   4609005          011  50548989
# 2675  11843  ...      RS      <NA>  91030530           51  33585109
# 2676  16462  ...    <NA>      <NA>   6029900           11  36814011
#
#      DDD_FAX_RESP  FAX_RESP                   EMAIL_RESP        CNPJ_AUDITOR  \
# 2674         <NA>      <NA>  renno@setaatacadista.com.br  00.115.909/0001-95
# 2675           51  33585176   michael.ceitlin@gem.ind.br  61.562.112/0001-20
# 2676           11  36844630   4000.isola@bradesco.com.br  57.755.217/0001-29
#
#                                                 AUDITOR
# 2674                     MS AUDITORES INDEPENDENTES S/C
# 2675  PRICEWATERHOUSECOOPERS AUDITORES INDEPENDENTES...
# 2676                 KPMG AUDITORES INDEPENDENTES LTDA.
#
# [3 rows x 47 columns]

# %%
df.shape
# Out:
# (2677, 47)

# %%
df.isnull().sum()
# Out:
# CNPJ_CIA                 0
# DENOM_SOCIAL             0
# DENOM_COMERC            95
# DT_REG                   0
# DT_CONST               929
# DT_CANCEL              765
# MOTIVO_CANCEL          767
# SIT                      0
# DT_INI_SIT               0
# CD_CVM                   0
# SETOR_ATIV               6
# TP_MERC               1904
# CATEG_REG             1239
# DT_INI_CATEG          1239
# SIT_EMISSOR           1330
# DT_INI_SIT_EMISSOR    1330
# CONTROLE_ACIONARIO       2
# TP_ENDER                 1
# LOGRADOURO               1
# COMPL                 1204
# BAIRRO                 645
# MUN                      1
# UF                       1
# PAIS                    91
# CEP                      2
# DDD_TEL                 25
# TEL                     25
# DDD_FAX                874
# FAX                    861
# EMAIL                  901
# TP_RESP                 70
# RESP                    70
# DT_INI_RESP             70
# LOGRADOURO_RESP         73
# COMPL_RESP            1280
# BAIRRO_RESP            769
# MUN_RESP                93
# UF_RESP                326
# PAIS_RESP             2655
# CEP_RESP                72
# DDD_TEL_RESP            74
# TEL_RESP                75
# DDD_FAX_RESP           919
# FAX_RESP              1458
# EMAIL_RESP             888
# CNPJ_AUDITOR           100
# AUDITOR                100
# dtype: int64

# %%
df.dtypes
# Out:
# CNPJ_CIA              string[python]
# DENOM_SOCIAL          string[python]
# DENOM_COMERC          string[python]
# DT_REG                datetime64[ns]
# DT_CONST              datetime64[ns]
# DT_CANCEL             datetime64[ns]
# MOTIVO_CANCEL         string[python]
# SIT                   string[python]
# DT_INI_SIT            datetime64[ns]
# CD_CVM                string[python]
# SETOR_ATIV            string[python]
# TP_MERC               string[python]
# CATEG_REG             string[python]
# DT_INI_CATEG          datetime64[ns]
# SIT_EMISSOR           string[python]
# DT_INI_SIT_EMISSOR    datetime64[ns]
# CONTROLE_ACIONARIO    string[python]
# TP_ENDER              string[python]
# LOGRADOURO            string[python]
# COMPL                 string[python]
# BAIRRO                string[python]
# MUN                   string[python]
# UF                    string[python]
# PAIS                  string[python]
# CEP                   string[python]
# DDD_TEL               string[python]
# TEL                   string[python]
# DDD_FAX               string[python]
# FAX                   string[python]
# EMAIL                 string[python]
# TP_RESP               string[python]
# RESP                  string[python]
# DT_INI_RESP           datetime64[ns]
# LOGRADOURO_RESP       string[python]
# COMPL_RESP            string[python]
# BAIRRO_RESP           string[python]
# MUN_RESP              string[python]
# UF_RESP               string[python]
# PAIS_RESP             string[python]
# CEP_RESP              string[python]
# DDD_TEL_RESP          string[python]
# TEL_RESP              string[python]
# DDD_FAX_RESP          string[python]
# FAX_RESP              string[python]
# EMAIL_RESP            string[python]
# CNPJ_AUDITOR          string[python]
# AUDITOR               string[python]
# dtype: object

# %%
key_cols = df.columns.tolist()
duplicados = df[df.duplicated(subset=key_cols, keep=False)]
print(len(duplicados))
# Out:
# 0
