# %%
from pipelines.readers.pipelines.cvm_formulario_demonstracoes_financeiras_padronizadas.reader_parquet_cvm import ReaderParquetCVMDFP as dfp

# %%
df = dfp().read("BPA_con")

# %%
df.tail(3)
# Out:
#                   CNPJ_CIA   DT_REFER  VERSAO             DENOM_CIA  CD_CVM  \
# 777008  64.904.295/0001-03 2026-02-28       1  CAMIL ALIMENTOS S.A.  024228
# 777009  64.904.295/0001-03 2026-02-28       1  CAMIL ALIMENTOS S.A.  024228
# 777010  64.904.295/0001-03 2026-02-28       1  CAMIL ALIMENTOS S.A.  024228
#
#                                          GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 777008  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 777009  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 777010  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
#
#        ORDEM_EXERC DT_FIM_EXERC       CD_CONTA            DS_CONTA   VL_CONTA  \
# 777008      ÚLTIMO   2026-02-28  1.02.04.01.02  Outros intangíveis  1155075.0
# 777009   PENÚLTIMO   2025-02-28     1.02.04.02            Goodwill        0.0
# 777010      ÚLTIMO   2026-02-28     1.02.04.02            Goodwill        0.0
#
#        ST_CONTA_FIXA ORIGEM_FORMULARIO
# ...

# %%
df.isnull().sum()
# Out:
# CNPJ_CIA             0
# DT_REFER             0
# VERSAO               0
# DENOM_CIA            0
# CD_CVM               0
# GRUPO_DFP            0
# MOEDA                0
# ESCALA_MOEDA         0
# ORDEM_EXERC          0
# DT_FIM_EXERC         0
# CD_CONTA             0
# DS_CONTA             0
# VL_CONTA             0
# ST_CONTA_FIXA        0
# ORIGEM_FORMULARIO    0
# dtype: int64

# %%
df.dtypes
# Out:
# CNPJ_CIA             string[python]
# DT_REFER             datetime64[ns]
# VERSAO                        Int64
# DENOM_CIA            string[python]
# CD_CVM               string[python]
# GRUPO_DFP            string[python]
# MOEDA                string[python]
# ESCALA_MOEDA         string[python]
# ORDEM_EXERC          string[python]
# DT_FIM_EXERC         datetime64[ns]
# CD_CONTA             string[python]
# DS_CONTA             string[python]
# VL_CONTA                    float64
# ST_CONTA_FIXA        string[python]
# ORIGEM_FORMULARIO            object
# dtype: object

# %%
key_cols = df.columns.tolist()
duplicados = df[df.duplicated(subset=key_cols, keep=False)]
print(len(duplicados))
# Out:
# 5952
