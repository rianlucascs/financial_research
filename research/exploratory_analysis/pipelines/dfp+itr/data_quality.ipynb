# %%
from pipelines.readers.data_preparation.cvm_balanco_patrimonial import CVMBalancoPatrimonial, EquityIdentifier, AccountIdentifier

# %%
cvm_balanco_patrimonial = CVMBalancoPatrimonial()
demonstration_code = "DRE_con"

df = cvm_balanco_patrimonial.read(
    search_equity=EquityIdentifier(denom_cia='VALE S.A.', cnpj_cia="33.592.510/0001-54", cd_cvm="4170"),
    demonstration_code=demonstration_code,
    search_account=AccountIdentifier(cd_conta="3.03", ds_conta="Receita Líquida de Vendas e/ou Serviços"),
)

# %%
df.tail(8)
# Out:
#               CNPJ_CIA   DT_REFER  VERSAO  DENOM_CIA  CD_CVM  \
# 54  33.592.510/0001-54 2024-09-30       1  VALE S.A.  004170
# 55  33.592.510/0001-54 2024-12-31       3  VALE S.A.  004170
# 56  33.592.510/0001-54 2025-03-31       2  VALE S.A.  004170
# 57  33.592.510/0001-54 2025-06-30       1  VALE S.A.  004170
# 58  33.592.510/0001-54 2025-09-30       1  VALE S.A.  004170
# 59  33.592.510/0001-54 2025-12-31       2  VALE S.A.  004170
# 60  33.592.510/0001-54 2026-03-31       1  VALE S.A.  004170
# 61  33.592.510/0001-54 2026-06-30       3  VALE S.A.  004170
#
#                                      GRUPO_DFP MOEDA ESCALA_MOEDA ORDEM_EXERC  \
# 54  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 55  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 56  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 57  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 58  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 59  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 60  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 61  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
#
#    DT_INI_EXERC DT_FIM_EXERC CD_CONTA         DS_CONTA    VL_CONTA  \
# 54   2024-07-01   2024-09-30     3.03  Resultado Bruto  18151000.0
# 55   2024-01-01   2024-12-31     3.03  Resultado Bruto  74687000.0
# 56   2025-01-01   2025-03-31     3.03  Resultado Bruto  15600000.0
# 57   2025-04-01   2025-06-30     3.03  Resultado Bruto  15386000.0
# 58   2025-07-01   2025-09-30     3.03  Resultado Bruto  20624000.0
# 59   2025-01-01   2025-12-31     3.03  Resultado Bruto  74708000.0
# 60   2026-01-01   2026-03-31     3.03  Resultado Bruto  16257000.0
# 61   2026-04-01   2026-06-30     3.03  Resultado Bruto  16179000.0
#
#    ST_CONTA_FIXA ORIGEM_FORMULARIO  INTERVALO_EXERC   ANO  VL_CONTA_TRI
# 54             S               ITR               91  2024    18151000.0
# 55             S               DFP              365  2024    22638000.0
# 56             S               ITR               89  2025    15600000.0
# 57             S               ITR               90  2025    15386000.0
# 58             S               ITR               91  2025    20624000.0
# 59             S               DFP              364  2025    23098000.0
# 60             S               ITR               89  2026    16257000.0
# 61             S               ITR               90  2026    16179000.0

# %%
df.isnull().sum()
# Out:
# CNPJ_CIA             0
# DT_REFER             0
# VERSAO               0
# DENOM_CIA            0
# CD_CVM               0
# GRUPO_DFP            0
# MOEDA                0
# ESCALA_MOEDA         0
# ORDEM_EXERC          0
# DT_INI_EXERC         0
# DT_FIM_EXERC         0
# CD_CONTA             0
# DS_CONTA             0
# VL_CONTA             0
# ST_CONTA_FIXA        0
# ORIGEM_FORMULARIO    0
# INTERVALO_EXERC      0
# ANO                  0
# VL_CONTA_TRI         0
# dtype: int64

# %%
df.dtypes
# Out:
# CNPJ_CIA             string[python]
# DT_REFER             datetime64[ns]
# VERSAO                        Int64
# DENOM_CIA            string[python]
# CD_CVM               string[python]
# GRUPO_DFP            string[python]
# MOEDA                string[python]
# ESCALA_MOEDA         string[python]
# ORDEM_EXERC          string[python]
# DT_INI_EXERC         datetime64[ns]
# DT_FIM_EXERC         datetime64[ns]
# CD_CONTA             string[python]
# DS_CONTA             string[python]
# VL_CONTA                    float64
# ST_CONTA_FIXA        string[python]
# ORIGEM_FORMULARIO            object
# INTERVALO_EXERC               int64
# ANO                           int32
# VL_CONTA_TRI                float64
# dtype: object

# %%
key_cols = df.columns.tolist()
duplicados = df[df.duplicated(subset=key_cols, keep=False)]
print(len(duplicados))
# Out:
# 0
